# %%
import gym
import random
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
from tensorflow.compat.v1.keras import Sequential
from collections import deque
from tensorflow.compat.v1.keras.layers import Dense
from tensorflow.compat.v1.keras.optimizers import Adam
import matplotlib.pyplot as plt
from tensorflow.compat.v1.keras.activations import relu, linear
import pickle

# %%
import numpy as np
env = gym.make('LunarLander-v2')
env.seed(0)
np.random.seed(0)
# Out:
# [2021-11-28 17:17:43,227] Making new env: LunarLander-v2

# %%
class DQN:

    """ Implementation of deep q learning algorithm """

    def __init__(self, action_space, state_space):

        self.action_space = action_space
        self.state_space = state_space
        self.epsilon = 1.0
        self.gamma = .99
        self.batch_size = 64
        self.epsilon_min = .01
        self.lr = 0.001
        self.epsilon_decay = .996
        self.memory = deque(maxlen=1000000)
        self.model = self.build_model()

    def build_model(self):

        model = Sequential()
        model.add(Dense(150, input_dim=self.state_space, activation=relu))
        model.add(Dense(120, activation=relu))
        model.add(Dense(self.action_space, activation=linear))
        model.compile(loss='mse', optimizer=Adam(lr=self.lr))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):

        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_space)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])

    def replay(self):

        if len(self.memory) < self.batch_size:
            return

        minibatch = random.sample(self.memory, self.batch_size)
        states = np.array([i[0] for i in minibatch])
        actions = np.array([i[1] for i in minibatch])
        rewards = np.array([i[2] for i in minibatch])
        next_states = np.array([i[3] for i in minibatch])
        dones = np.array([i[4] for i in minibatch])

        states = np.squeeze(states)
        next_states = np.squeeze(next_states)

        targets = rewards + self.gamma*(np.amax(self.model.predict_on_batch(next_states), axis=1))*(1-dones)
        targets_full = self.model.predict_on_batch(states)
        ind = np.array([i for i in range(self.batch_size)])
        loss = (targets_full[[ind], [actions]] - targets)**2 
        targets_full[[ind], [actions]] = targets

        self.model.fit(states, targets_full, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return np.mean(loss)

# %%
def train_dqn(episode):

    loss = []
    agent = DQN(env.action_space.n, env.observation_space.shape[0])
    meanError =  []
    for e in range(episode):
        state = env.reset()
        state = np.reshape(state, (1, 8))
        score = 0
        max_steps = 3000
        stepErrors = []
        for i in range(max_steps):
            action = agent.act(state)
            env.render()
            next_state, reward, done, _ = env.step(action)
            score += reward
            next_state = np.reshape(next_state, (1, 8))
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            error = agent.replay()
            if error is not None:
                stepErrors.append(error)
            if done:
                print("episode: {}/{}, score: {}".format(e, episode, score))
                break
        loss.append(score)
        meanError.append(np.mean(stepErrors))

        # Average score of last 100 episode
        is_solved = np.mean(loss[-100:])
        if is_solved > 200:
            print('\n Task Completed! \n')
            break
        print("Average over last 100 episode: {0:.2f} \n".format(is_solved))
    return loss,meanError

# %%
if __name__ == '__main__':

    print(env.observation_space)
    print(env.action_space)
    episodes = 400
    loss,meanError = train_dqn(episodes)
    pickle.dump(loss, open("runLosses.p", "wb" ) )  
    pickle.dump(meanError, open("meanErrors.p", "wb" ) )  
    plt.plot([i+1 for i in range(0, len(loss), 2)], loss[::2])
    plt.show()
# Out:
# Box(8,)
# Discrete(4)
# episode: 0/400, score: -384.5824241681966
# Average over last 100 episode: -384.58
#
# episode: 1/400, score: -193.93825171306588
# Average over last 100 episode: -289.26
#
# episode: 2/400, score: -397.5105277991687
# Average over last 100 episode: -325.34
#
# episode: 3/400, score: -192.3152222283839
# Average over last 100 episode: -292.09
#
# episode: 4/400, score: -329.0991301417556
# Average over last 100 episode: -299.49
#
# Average over last 100 episode: 146.55
#
# episode: 217/400, score: 187.40353043270954
# Average over last 100 episode: 146.81
#
# episode: 218/400, score: 231.10246912951814
# Average over last 100 episode: 147.21
#
# episode: 219/400, score: 204.18785023730442
# Average over last 100 episode: 150.89
#
# episode: 220/400, score: 231.28191434589132
# Average over last 100 episode: 151.46
#
# episode: 221/400, score: 217.2676683032808
# Average over last 100 episode: 151.70
#
# episode: 222/400, score: 128.33387308828165
# Average over last 100 episode: 151.37
#
# episode: 223/400, score: 148.70078315942746
# Average over last 100 episode: 150.90
#
# episode: 224/400, score: 224.65090292766573
# Average over last 100 episode: 151.32
#
# episode: 225/400, score: 228.4128080585663
# Average over last 100 episode: 151.61
#
# episode: 226/400, score: 208.03929687639427
# Average over last 100 episode: 151.40
#
# episode: 227/400, score: 206.46074449665605
# Average over last 100 episode: 151.38
#
# episode: 228/400, score: 233.33571379702215
# Average over last 100 episode: 151.61
#
# episode: 229/400, score: 187.60274957025948
# Average over last 100 episode: 151.25
#
# episode: 230/400, score: 213.0113014928093
# Average over last 100 episode: 151.35
#
# episode: 231/400, score: 231.69762845423767
# Average over last 100 episode: 151.66
#
# episode: 232/400, score: -1009.1611862709606
# Average over last 100 episode: 139.53
#
# episode: 233/400, score: 189.6620183960671
# Average over last 100 episode: 139.41
#
# episode: 234/400, score: 180.67118325384945
# Average over last 100 episode: 139.26
#
# episode: 235/400, score: 225.32236371547228
# Average over last 100 episode: 139.99
#
# episode: 236/400, score: 215.01555791841605
# Average over last 100 episode: 142.30
#
# episode: 237/400, score: 199.92963227921717
# Average over last 100 episode: 142.58
#
# episode: 238/400, score: 205.94032235368732
# Average over last 100 episode: 144.97
#
# episode: 239/400, score: 233.37461723012092
# Average over last 100 episode: 145.44
#
# episode: 240/400, score: 238.42021055058981
# Average over last 100 episode: 146.92
#
# episode: 241/400, score: 245.14670862313858
# Average over last 100 episode: 147.72
#
# episode: 242/400, score: 244.6970405951172
# Average over last 100 episode: 151.58
#
# episode: 243/400, score: 158.48279491852716
# Average over last 100 episode: 153.98
#
# episode: 244/400, score: -14.323720848463424
# Average over last 100 episode: 154.29
#
# episode: 245/400, score: 252.1342940799741
# Average over last 100 episode: 157.62
#
# episode: 246/400, score: 199.25824441691944
# Average over last 100 episode: 162.77
#
# episode: 247/400, score: 229.03604812725084
# Average over last 100 episode: 163.22
#
# episode: 248/400, score: 176.22321125838573
# Average over last 100 episode: 162.63
#
# episode: 249/400, score: 209.4573142045207
# Average over last 100 episode: 163.39
#
# episode: 250/400, score: 225.90027703547528
# Average over last 100 episode: 163.74
#
# episode: 251/400, score: 198.34795724747988
# Average over last 100 episode: 163.47
#
# episode: 252/400, score: 258.78305552915265
# Average over last 100 episode: 164.07
#
# episode: 253/400, score: 191.6741280123302
# Average over last 100 episode: 163.83
#
# episode: 254/400, score: 259.77437581598076
# Average over last 100 episode: 164.27
#
# episode: 255/400, score: 225.7840962071549
# Average over last 100 episode: 164.53
#
# episode: 256/400, score: 224.91261536441857
# Average over last 100 episode: 164.99
#
# episode: 257/400, score: 171.41342149017495
# Average over last 100 episode: 164.31
#
# episode: 258/400, score: 179.50662481249407
# Average over last 100 episode: 163.96
#
# episode: 386/400, score: 227.77865128471592
# Average over last 100 episode: 164.17
#
# episode: 387/400, score: 217.1916369011515
# Average over last 100 episode: 164.08
#
# episode: 388/400, score: 205.98144552679588
# Average over last 100 episode: 164.07
#
# episode: 389/400, score: 191.09224768452947
# Average over last 100 episode: 163.76
#
# episode: 390/400, score: 138.52197153035775
# Average over last 100 episode: 163.10
#
# episode: 391/400, score: 209.21904884169948
# Average over last 100 episode: 166.05
#
# episode: 392/400, score: 182.9322178043659
# Average over last 100 episode: 165.83
# episode: 393/400, score: 198.17108438597847
# Average over last 100 episode: 168.27
#
# episode: 394/400, score: 216.6261913302091
# Average over last 100 episode: 168.22
#
# episode: 395/400, score: 224.5970791900989
# Average over last 100 episode: 168.21
#
# episode: 396/400, score: 216.82012173767964
# Average over last 100 episode: 168.30
#
# episode: 397/400, score: 212.4230230469897
# Average over last 100 episode: 168.24
#
# episode: 398/400, score: 227.10424639754348
# Average over last 100 episode: 168.48
#
# episode: 399/400, score: -678.8787993763048
# Average over last 100 episode: 162.75
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16452/4153673476.py in <module>
#       5     episodes = 400
#       6     loss,meanError = train_dqn(episodes)
# ----> 7     pickle.dump(loss, open("runLosses.p", "wb" ) )
#       8     pickle.dump(meanError, open("meanErrors.p", "wb" ) )
#       9     plt.plot([i+1 for i in range(0, len(loss), 2)], loss[::2])
#
# NameError: name 'pickle' is not defined

# %%
# %debug
# Out:
# > d:\miniconda\envs\tf-gpu\lib\site-packages\numpy\core\_methods.py(178)_mean()
#     176             is_float16_result = True
#     177
# --> 178     ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     179     if isinstance(ret, mu.ndarray):
#     180         ret = um.true_divide(
#
# ipdb> u
# > d:\miniconda\envs\tf-gpu\lib\site-packages\numpy\core\fromnumeric.py(3419)mean()
#    3417             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3418
# -> 3419     return _methods._mean(a, axis=axis, dtype=dtype,
#    3420                           out=out, **kwargs)
#    3421
#
# ipdb> ı
# *** NameError: name 'ı' is not defined
# ipdb> u
# > <__array_function__ internals>(5)mean()
#
# ipdb> u
# > c:\users\orkun\appdata\local\temp\ipykernel_16452\1951836626.py(26)train_dqn()
#
# ipdb> u
# > c:\users\orkun\appdata\local\temp\ipykernel_16452\4153673476.py(6)<module>()
#
# ipdb> stepErrors
# *** NameError: name 'stepErrors' is not defined
# ipdb> u
# *** Oldest frame
# ipdb> u
# *** Oldest frame
# ipdb> stepErros
# *** NameError: name 'stepErros' is not defined
# ipdb> stepErrors
# *** NameError: name 'stepErrors' is not defined
# ipdb> d
# > c:\users\orkun\appdata\local\temp\ipykernel_16452\1951836626.py(26)train_dqn()
#
# ipdb> stepErrors
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 3.126450236020556, 3.0467041194260682, 2.8791953098060223, 2.711949300827965, 2.5750395962926502, 2.39831101307278, 2.191663278091612, 1.9750236255176872, 1.9986204821637945, 1.8940488455350963, 1.7694222603578917, 1.6132198231191708, 1.3897183292096749, 1.4624772087896427, 1.4354154395249938, 1.4576515433482173, 1.7147367370640403, 2.0996942207779785, 2.019757608421516, 1.9994483335699267, 2.590094518735662, 9.962249732484208, 157.18622219636623]
# ipdb> np.mean(stepErrors)
# *** TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'
# ipdb> eror
# *** NameError: name 'eror' is not defined
# ipdb> error
# 157.18622219636623
# ipdb> q
